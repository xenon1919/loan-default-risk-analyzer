# %% [markdown]
# # Import necessary packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Load the dataset

# %%
df = pd.read_csv("../data/raw/loan_default_dataset_v2.csv")

# %% [markdown]
# # Covariance Matrix

# %%
df.cov()
# Out:
#                            age  annual_income   credit_score   loan_amount  \
# age                 164.984904   3.025963e+04      18.583440 -4.324599e+04
# annual_income     30259.630344   3.145691e+10  406946.935864 -3.849818e+08
# credit_score         18.583440   4.069469e+05    3751.683722  5.220198e+05
# loan_amount      -43245.987437  -3.849818e+08  522019.820731  1.199573e+11
# interest_rate        -0.423684  -9.061959e+03      -4.699666 -5.188137e+04
# employment_years     -5.914229   3.317897e+04     -12.420968  2.763811e+04
# default               0.011018  -1.983122e+03      -0.421775  9.068571e+03
#
#                   interest_rate  employment_years      default
# age                   -0.423684         -5.914229     0.011018
# annual_income      -9061.959410      33178.969851 -1983.122153
# credit_score          -4.699666        -12.420968    -0.421775
# loan_amount       -51881.365884      27638.107204  9068.571309
# interest_rate         14.287367         -1.217716    -0.005563
# employment_years      -1.217716         99.854630    -0.081276
# default               -0.005563         -0.081276     0.026297

# %% [markdown]
# # Correlation Matrix

# %%
corr = df.corr()
corr
# Out:
#                        age  annual_income  credit_score  loan_amount  \
# age               1.000000       0.013283      0.023621    -0.009721
# annual_income     0.013283       1.000000      0.037460    -0.006267
# credit_score      0.023621       0.037460      1.000000     0.024607
# loan_amount      -0.009721      -0.006267      0.024607     1.000000
# interest_rate    -0.008727      -0.013517     -0.020299    -0.039630
# employment_years -0.046078       0.018721     -0.020294     0.007986
# default           0.005290      -0.068950     -0.042463     0.161462
#
#                   interest_rate  employment_years   default
# age                   -0.008727         -0.046078  0.005290
# annual_income         -0.013517          0.018721 -0.068950
# credit_score          -0.020299         -0.020294 -0.042463
# loan_amount           -0.039630          0.007986  0.161462
# interest_rate          1.000000         -0.032239 -0.009075
# employment_years      -0.032239          1.000000 -0.050156
# default               -0.009075         -0.050156  1.000000

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(corr, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Heatmap")
plt.show()
