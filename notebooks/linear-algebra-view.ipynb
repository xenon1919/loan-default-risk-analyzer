# %% [markdown]
# # Import necessary packages

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# # Load the dataset

# %%
df = pd.read_csv("../data/raw/loan_default_dataset_v2.csv")

# %% [markdown]
# ## Split X and y

# %%
X = df.drop(columns=["default"])
y = df["default"]

# %% [markdown]
# ## Data as a Matrix

# %%
X.values.shape
# Out:
# (1000, 6)

# %% [markdown]
# ##  One Prediction = Dot Product

# %%
x_i = X.iloc[0].values

# %% [markdown]
# ## Create fake weights

# %%
w = np.random.randn(X.shape[1])

# %% [markdown]
# ## Dot product

# %%
np.dot(x_i, w)
# Out:
# np.float64(-512454.6171954225)

# %% [markdown]
# ## Scaling Changes Geometry

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
X_scaled[0]
# Out:
# array([-1.34434514,  2.22423804,  0.18596711, -1.57405276,  0.18331887,
#         1.02275479])
